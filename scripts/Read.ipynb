# %% [markdown]
# # Lectura e interpretaciòn de datos obtenidos en jornada de control contra la hipertensiòn

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

df = pd.read_csv("../data//T.A-F1.csv")
df = df.drop("y", axis=1)
df
# Out:
#     F1  F2          F3                                      F4       F5  \
# 0   Sí  Sí     Ninguna                                 Ninguna  Ninguna
# 1   No  Sí     Ninguna                                 Ninguna  Ninguna
# 2   No  Sí     Ninguna                                 Ninguna       No
# 3   No  Sí     Ninguna                                 Ninguna       Sí
# 4   No  No     Ninguna                                 Ninguna       No
# 5   No  No     Ninguna                                 Ninguna       No
# 6   Sí  Sí  Medicación                            Anticálcicos       Sí
# 7   No  Sí     Ninguna                                 Ninguna       No
# 8   No  No     Ninguna                                 Ninguna       No
# 9   No  Sí     Ninguna                                 Ninguna       Sí
# 10  Sí  Sí     Ninguna                                 Ninguna       No
# 11  No  Sí     Ninguna                                 Ninguna       Sí
# 12  No  No     Ninguna                                 Ninguna       Sí
# 13  Sí  Sí  Medicación            Otros farmácos hipertensivos       Sí
# 14  No  Sí     Ninguna                                 Ninguna       No
# 15  No  Sí     Ninguna                                 Ninguna       Sí
# 16  No  No     Ninguna                                 Ninguna       Sí
# 17  No  Sí     Ninguna                                 Ninguna       No
# 18  No  Sí  Medicación            Otros farmácos hipertensivos       Sí
# 19  No  Sí     Ninguna                                 Ninguna       No
# 20  No  No     Ninguna                                 Ninguna       No
# 21  No  No     Ninguna                                 Ninguna       No
# 22  No  Sí     Ninguna                                 Ninguna       No
# 23  Sí  Sí  Medicación            Otros farmácos hipertensivos       Sí
# 24  No  Sí     Ninguna                                 Ninguna       No
# 25  No  No     Ninguna                                 Ninguna       No
# 26  No  No     Ninguna                                 Ninguna       No
# 27  No  Sí     Ninguna                                 Ninguna       No
# 28  No  No     Ninguna                                 Ninguna       No
# 29  No  No     Ninguna                                 Ninguna       No
# 30  No  No     Ninguna                                 Ninguna       No
# 31  No  Sí     Ninguna                                 Ninguna       No
# 32  Sí  No  Medicación            Otros farmácos hipertensivos       Sí
# 33  No  Sí     Ninguna                                 Ninguna       Sí
# 34  Sí  Sí  Medicación  Otros farmácos de efecto no reconocido       Sí
# 35  No  No  Medicación                              Diuréticos       Sí
# 36  Sí  No  Medicación            Otros farmácos hipertensivos       Sí
# 37  No  No     Ninguna                                 Ninguna       No
# 38  No  No     Ninguna                                 Ninguna       No
# 39  No  Sí  Medicación  Otros farmácos de efecto no reconocido       No
# 40  No  No  Medicación                         Betabloqueantes       Sí
# 41  Sí  No  Medicación                              Diuréticos       Sí
# 42  No  Sí     Ninguna                                 Ninguna       Sí
# 43  No  No     Ninguna                                 Ninguna       No
# 44  No  No     Ninguna                                 Ninguna       No
# 45  No  No     Ninguna                                 Ninguna       No
# 46  No  No     Ninguna                                 Ninguna       No
#
#          F6
# 0   Ninguna
# 1   Ninguna
# 2        Sí
# 3        Sí
# 4        No
# 5        No
# 6        Sí
# 7        Sí
# 8        Sí
# 9        Sí
# 10       No
# 11       Sí
# 12       Sí
# 13       Sí
# 14       No
# 15       Sí
# 16       Sí
# 17       Sí
# 18     Pami
# 19       Sí
# 20       No
# 21       No
# 22       No
# 23       Sí
# 24       No
# 25       No
# 26       No
# 27       No
# 28       No
# 29       No
# 30       No
# 31       No
# 32       Sí
# 33       Sí
# 34       Sí
# 35       Sí
# 36       Sí
# 37       No
# 38       No
# 39       Sí
# 40       Sí
# 41       Sí
# 42       Sí
# 43       No
# 44       No
# 45       No
# 46       No

# %% [markdown]
# ### Mediante el presente se realizaran analisis en conjunto con librerias de datos para extraer las respuestas consecuentes a el formulario
# #### Las aristas a procesar son las siguentes:
# ##### -Posee algún problema asociado a su tensión arterial?
# ##### -Tiene antecedentes familiares con problemas asociados a su tensión arterial?
# ##### -En este momento esta llevando a cabo algún tratamiento indicado por un profesional de la salud para mantener controlada su tensión arterial?
# ##### -En caso de tener recetada medicación, indique en qué grupo entra.
# ##### -Puede disponer de la medicación recetada?
# ##### -Posee los recursos económicos para abastecerse de esta?

# %% [markdown]
# ###### Se aprecia graficamente las respuestas a la primera incognita "-Posee algún problema asociado a su tensión arterial? " como "Formulario 1" y en "Formulario 2" la pregunta siguiente "-Tiene antecedentes familiares con problemas asociados a su tensión arterial?"

# %%
s = df.loc[df["F1"] == "Sí"].count()[0]
n = df.loc[df["F1"] == "No"].count()[0]
labels = ["Sí", "No"]
colors = ["#32cd32", "#BA110C"]
plt.figure(figsize=(8,5))
plt.title("-Posee algún problema asociado a su tensión arterial? ")
plt.pie([s, n], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()

s = df.loc[df["F2"] == "Sí"].count()[0]
n = df.loc[df["F2"] == "No"].count()[0]
labels = ["Sí", "No"]
colors = ["#32cd32", "#BA110C"]
plt.figure(figsize=(8,5))
plt.title("-Tiene antecedentes familiares con problemas asociados a su tensión arterial?")
plt.pie([s, n], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3961911267.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = df.loc[df["F1"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3961911267.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = df.loc[df["F1"] == "No"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3961911267.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = df.loc[df["F2"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3961911267.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = df.loc[df["F2"] == "No"].count()[0]

# %% [markdown]
# #### Mediante los siguientes graficos podemos preguntarnos tambien que porcentaje de los que si tienen problematicas asociadas tienen relacion congenita
# ##### Teniendo en cuenta que el 19.15% de los 46 encuestados resulta en 9, podemos cuncluir que 5 de estos son los que tienen familiares implicados reposandonos en el 51.06% que respondieron el Formulario 2

# %%
htp = df.loc[df["F1"] == "Sí"]
s = htp.loc[df["F3"] == "Medicación"].count()[0]
n = htp.loc[df["F3"] == "Ninguna"].count()[0]
labels = ["Medicación", "No Medicado"]
colors = ["#32cd32", "#BA110C"]
plt.figure(figsize=(8,5))
plt.title("-En este momento esta llevando a cabo algún tratamiento indicado por un profesional de la salud para mantener controlada su tensión arterial? ")
plt.pie([s, n], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2460299364.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = htp.loc[df["F3"] == "Medicación"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2460299364.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = htp.loc[df["F3"] == "Ninguna"].count()[0]

# %% [markdown]
# #### Traducimos el 22.22% en 2 personas de los encuestados que no se tratan a nivel clinico por su hipertension declarada

# %%
ca = df.loc[df["F4"] == "Ninguna"].count()[0]
cb = df.loc[df["F4"] == "Anticálcicos"].count()[0]
cc = df.loc[df["F4"] == "Otros farmácos de efecto no reconocido"].count()[0]
cd = df.loc[df["F4"] == "Diuréticos"].count()[0]
ce = df.loc[df["F4"] == "Otros farmácos hipertensivos"].count()[0]
cf = df.loc[df["F4"] == "Betabloqueantes"].count()[0]
explode = (0, 0.1, 0, 0, 0, 0.08)
labels = ["Ninguna", "Anticálcicos", "Otros farmácos de efecto no reconocido", "Diuréticos", "Otros farmácos hipertensivos", "Betabloqueantes"]
colors = ["#35cd32", "#BA110C", "#CA107C", "#BA210C", "#BA710C", "#BA410C"]
plt.figure(figsize=(8,5))
plt.title("-En caso de tener recetada medicación, indique en qué grupo entra.")
plt.pie([ca, cb, cc, cd, ce, cf], labels=labels, colors=colors, explode=explode, autopct="%.2f %%")
plt.show()

cb = df.loc[df["F4"] == "Anticálcicos"].count()[0]
cc = df.loc[df["F4"] == "Otros farmácos de efecto no reconocido"].count()[0]
cd = df.loc[df["F4"] == "Diuréticos"].count()[0]
ce = df.loc[df["F4"] == "Otros farmácos hipertensivos"].count()[0]
cf = df.loc[df["F4"] == "Betabloqueantes"].count()[0]
explode = (0.1, 0, 0, 0, 0.08)
labels = ["Anticálcicos", "Otros farmácos de efecto no reconocido", "Diuréticos", "Otros farmácos hipertensivos", "Betabloqueantes"]
colors = ["#32cd32", "#BA150C", "#BA417C", "#BA210C", "#BA710C", "#BA410C"]
plt.figure(figsize=(8,5))
plt.title("-En caso de tener recetada medicación, indique en qué grupo entra.")
plt.pie([cb, cc, cd, ce, cf], labels=labels, colors=colors, explode=explode, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ca = df.loc[df["F4"] == "Ninguna"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cb = df.loc[df["F4"] == "Anticálcicos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cc = df.loc[df["F4"] == "Otros farmácos de efecto no reconocido"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cd = df.loc[df["F4"] == "Diuréticos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ce = df.loc[df["F4"] == "Otros farmácos hipertensivos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cf = df.loc[df["F4"] == "Betabloqueantes"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cb = df.loc[df["F4"] == "Anticálcicos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cc = df.loc[df["F4"] == "Otros farmácos de efecto no reconocido"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cd = df.loc[df["F4"] == "Diuréticos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ce = df.loc[df["F4"] == "Otros farmácos hipertensivos"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2725993006.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cf = df.loc[df["F4"] == "Betabloqueantes"].count()[0]

# %% [markdown]
# #### En la primera grafica vemos la totalidad de encuestados reflejados en la pregunta mientras que en el segundo observamos la cara positiva en hipertension

# %%
s = df.loc[df["F5"] == "Sí"].count()[0]
n = df.loc[df["F5"] == "No"].count()[0]
r = df.loc[df["F5"] == "Ninguna"].count()[0]
labels = ["Sí", "No", "Ninguna"]
colors = ["#32cd32", "#BA110C", "#8806CE"]
plt.figure(figsize=(8,5))
plt.title("-Puede disponer de la medicación recetada?")
plt.pie([s, n, r], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3502322379.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = df.loc[df["F5"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3502322379.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = df.loc[df["F5"] == "No"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\3502322379.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   r = df.loc[df["F5"] == "Ninguna"].count()[0]

# %%
ca = df.loc[df["F6"] == "Ninguna"].count()[0]
cb = df.loc[df["F6"] == "Sí"].count()[0]
cc = df.loc[df["F6"] == "No"].count()[0]
cd = df.loc[df["F6"] == "Pami"].count()[0]
explode = (0, 0, 0, 0.1)
labels = ["Ninguna", "Sí", "No", "Pami"]
colors = ["#32cd32", "#BA110C", "#BA117C", "#8806CE"]
plt.figure(figsize=(8,5))
plt.title("-Posee los recursos económicos para abastecerse de esta?")
plt.pie([ca, cb, cc, cd], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2244726219.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ca = df.loc[df["F6"] == "Ninguna"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2244726219.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cb = df.loc[df["F6"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2244726219.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cc = df.loc[df["F6"] == "No"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_26380\2244726219.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cd = df.loc[df["F6"] == "Pami"].count()[0]
