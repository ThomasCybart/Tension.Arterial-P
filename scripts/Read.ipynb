# %% [markdown]
# # Lectura e interpretaciòn de datos obtenidos en jornada de control contra la hipertensiòn

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

df = pd.read_csv("../data//T.A-F1.csv")
df = df.drop("y", axis=1)

df
# Out:
#     F1  F2          F3                                      F4   F5    F6
# 0   Sí  Sí         NaN                                     NaN  NaN   NaN
# 1   No  Sí         NaN                                     NaN  NaN   NaN
# 2   No  Sí     Ninguna                                 Ninguna   No    Sí
# 3   No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 4   No  No     Ninguna                                 Ninguna   No    No
# 5   No  No     Ninguna                                 Ninguna   No    No
# 6   Sí  Sí  Medicación                            Anticálcicos   Sí    Sí
# 7   No  Sí     Ninguna                                 Ninguna   No    Sí
# 8   No  No     Ninguna                                 Ninguna   No    Sí
# 9   No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 10  Sí  Sí     Ninguna                                 Ninguna   No    No
# 11  No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 12  No  No     Ninguna                                 Ninguna   Sí    Sí
# 13  Sí  Sí  Medicación            Otros farmácos hipertensivos   Sí    Sí
# 14  No  Sí     Ninguna                                 Ninguna   No    No
# 15  No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 16  No  No     Ninguna                                 Ninguna   Sí    Sí
# 17  No  Sí     Ninguna                                 Ninguna   No    Sí
# 18  No  Sí  Medicación            Otros farmácos hipertensivos   Sí  Pami
# 19  No  Sí     Ninguna                                 Ninguna   No    Sí
# 20  No  No     Ninguna                                 Ninguna   No    No
# 21  No  No     Ninguna                                 Ninguna   No    No
# 22  No  Sí     Ninguna                                 Ninguna   No    No
# 23  Sí  Sí  Medicación            Otros farmácos hipertensivos   Sí    Sí
# 24  No  Sí     Ninguna                                 Ninguna   No    No
# 25  No  No     Ninguna                                 Ninguna   No    No
# 26  No  No     Ninguna                                 Ninguna   No    No
# 27  No  Sí     Ninguna                                 Ninguna   No    No
# 28  No  No     Ninguna                                 Ninguna   No    No
# 29  No  No     Ninguna                                 Ninguna   No    No
# 30  No  No     Ninguna                                 Ninguna   No    No
# 31  No  Sí     Ninguna                                 Ninguna   No    No
# 32  Sí  No  Medicación            Otros farmácos hipertensivos   Sí    Sí
# 33  No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 34  Sí  Sí  Medicación  Otros farmácos de efecto no reconocido   Sí    Sí
# 35  No  No  Medicación                              Diuréticos   Sí    Sí
# 36  Sí  No  Medicación            Otros farmácos hipertensivos   Sí    Sí
# 37  No  No     Ninguna                                 Ninguna   No    No
# 38  No  No     Ninguna                                 Ninguna   No    No
# 39  No  Sí  Medicación  Otros farmácos de efecto no reconocido   No    Sí
# 40  No  No  Medicación                         Betabloqueantes   Sí    Sí
# 41  Sí  No  Medicación                              Diuréticos   Sí    Sí
# 42  No  Sí     Ninguna                                 Ninguna   Sí    Sí
# 43  No  No     Ninguna                                 Ninguna   No    No
# 44  No  No     Ninguna                                 Ninguna   No    No
# 45  No  No     Ninguna                                 Ninguna   No    No
# 46  No  No     Ninguna                                 Ninguna   No    No

# %% [markdown]
# ### Mediante el presente se realizaran analisis en conjunto con librerias de datos para extraer las respuestas consecuentes a el formulario
# #### Las aristas a procesar son las siguentes:
# ##### -Posee algún problema asociado a su tensión arterial?
# ##### -Tiene antecedentes familiares con problemas asociados a su tensión arterial?
# ##### -En este momento esta llevando a cabo algún tratamiento indicado por un profesional de la salud para mantener controlada su tensión arterial?
# ##### -En caso de tener recetada medicación, indique en qué grupo entra.
# ##### -Puede disponer de la medicación recetada?
# ##### -Posee los recursos económicos para abastecerse de esta?

# %% [markdown]
# ###### Se aprecia graficamente las respuestas a la primera incognita "-Posee algún problema asociado a su tensión arterial? " como "Formulario 1" y en "Formulario 2" la pregunta siguiente "-Tiene antecedentes familiares con problemas asociados a su tensión arterial?"

# %%
s = df.loc[df["F1"] == "Sí"].count()[0]
n = df.loc[df["F1"] == "No"].count()[0]
labels = ["Sí", "No"]
colors = ["#32cd32", "#BA110C"]
plt.figure(figsize=(8,5))
plt.title("Formulario 1")
plt.pie([s, n], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()

s = df.loc[df["F2"] == "Sí"].count()[0]
n = df.loc[df["F2"] == "No"].count()[0]
labels = ["Sí", "No"]
colors = ["#32cd32", "#BA110C"]
plt.figure(figsize=(8,5))
plt.title("Formulario 2")
plt.pie([s, n], labels=labels, colors=colors, autopct="%.2f %%")
plt.show()
# Out:
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_27800\3961609390.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = df.loc[df["F1"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_27800\3961609390.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = df.loc[df["F1"] == "No"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_27800\3961609390.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s = df.loc[df["F2"] == "Sí"].count()[0]
# C:\Users\Thoma\AppData\Local\Temp\ipykernel_27800\3961609390.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   n = df.loc[df["F2"] == "No"].count()[0]

# %% [markdown]
# #### Mediante los siguientes graficos podemos preguntarnos tambien que porcentaje de los que si tienen problematicas asociadas tienen relacion congenita
# ##### Teniendo en cuenta que el 19.15% de los 46 encuestados resulta en 9 podemos cuncluir que 5 de estos son los que tienen familiares implicados reposandonos en el 51.06% que respondieron el Formulario 2
